# %%
import sys
sys.path.append('/Users/albertsmith/Documents/GitHub.nosync/')
import SLEEPY as sl
sl.Defaults['verbose']=False

# %%
# %matplotlib notebook

# %%
ex=sl.ExpSys(v0H=200,Nucs='17O',LF=False,vr=0,pwdavg=sl.PowderAvg('zcw986'))
ex.set_inter('quadrupole',i=0,delta=64000)

seq=ex.Liouvillian().Sequence(Dt=1e-6)
rho=sl.Rho('17Ox','17Op')

# %%
rho.clear()
rho.DetProp(seq,n=4096)
# Out:
# Density Matrix/Detection Operator
# rho0: 17Ox
# detect[0]: 17Op
# Current time is 4096.000 microseconds
# 4096 time points have been recorded
#
# ...

# %%
ex.LF=[True]

seq=ex.Liouvillian().Sequence(Dt=1e-6)
rhoLF=sl.Rho('17Ox','17Op')

rhoLF.DetProp(seq,n=4096)
# Out:
# Density Matrix/Detection Operator
# rho0: 17Ox
# detect[0]: 17Op
# Current time is 4096.000 microseconds
# 4096 time points have been recorded
#
# ...

# %%
ax=rho.plot(FT=True,apodize=True,axis='ppm')
rhoLF.downmix()
rhoLF.plot(FT=True,apodize=True,ax=ax,axis='ppm')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='$\\delta$($^{17}$O) / ppm', ylabel='I / a.u.'>
