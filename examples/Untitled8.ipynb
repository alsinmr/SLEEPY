# %%
import sys
sys.path.append('/Users/albertsmith/Documents/GitHub.nosync/')
import SLEEPY as sl
import numpy as np

# %%
# %matplotlib notebook

# %%
theta=np.pi-np.arccos(1/3)
sl.Tools.D2([0,0,0],[0,np.pi/2,np.pi/2],[0,0,np.pi/2]).mean(0)
# Out:
# array([ 0.00000000e+00+2.49979981e-17j, -2.49979981e-17-2.49979981e-17j,
#         0.00000000e+00+0.00000000e+00j,  2.49979981e-17-2.49979981e-17j,
#         0.00000000e+00-2.49979981e-17j])

# %%
ex=sl.ExpSys(v0H=500,Nucs=['1H','1H','1H','1H','1H','1H'])
# ex=sl.ExpSys(v0H=500,Nucs=['1H','1H','1H'])
for i in range(6):
    ex.set_inter('CS',i=i,ppm=.333)
# ex.set_inter('J',i0=0,i1=1,J=15)
# ex.set_inter('J',i0=0,i1=2,J=15)
# ex.set_inter('J',i0=1,i1=2,J=15)
# ex.set_inter('J',i0=3,i1=4,J=15)
# ex.set_inter('J',i0=3,i1=5,J=15)
# ex.set_inter('J',i0=4,i1=5,J=15)

for i in range(3):
    for j in range(3,6):
        ex.set_inter('J',i0=i,i1=j,J=7.11)

# %%
L=ex.Liouvillian()
seq=L.Sequence().add_channel('1H',t=.001)

# %%
rho=sl.Rho(rho0='S0x',detect='S0p')
rho.DetProp(seq,n=10000)

rho.plot(FT=True,apodize=True)
# Out:
# State-space reduction: 4096->6
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='$\\nu$ / Hz', ylabel='I / a.u.'>
