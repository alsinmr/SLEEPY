# %%
import sys
sys.path.append('/Users/albertsmith/Documents/GitHub.nosync/')
import SLEEPY as sl

# %%
# %matplotlib notebook

# %%
ex0=sl.ExpSys(v0H=600,Nucs='2H',LF=True,vr=0)
ex0.set_inter('quadrupole',i=0,delta=128000)
ex1=ex0.copy()
ex1.set_inter('quadrupole',i=0,delta=64000)
# Out:
# 1-spin system (2H)
# B0 = 14.092 T (600.000 MHz 1H frequency)
# rotor angle = 0.000 degrees
# rotor frequency = 0.0 kHz
# Temperature = 298 K
# Powder Average: JCP59 with 99 angles
# Interactions:
# 	quadrupole on spin 0 with arguments: (delta=64000)
#
# ...

# %%
L=sl.Liouvillian((ex0,ex1))
# L=ex0.Liouvillian()
L.kex=sl.Tools.twoSite_kex(tc=5e-5,p1=.5)
# seq=L.Sequence().add_channel('2H',t=[0,ex0.taur/20])
seq=L.Sequence().add_channel('2H',t=[0,1e-6])

# %%
rho=sl.Rho(rho0='2Hx',detect='2Hp')
rho.DetProp(seq,n=200)
rho.downmix()

# %%
rho.plot(FT=True,apodize=True,axis='kHz')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='$\\nu$ / kHz', ylabel='I / a.u.'>

# %%
rho.plot(FT=True,apodize=True,axis='kHz')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='$\\nu$ / kHz', ylabel='I / a.u.'>
