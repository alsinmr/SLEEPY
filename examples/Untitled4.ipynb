# %%
# git clone https://github.com/alsinmr/pyRelaxSim.git
import sys
sys.path.append('/Users/albertsmith/Documents/GitHub.nosync')
sys.path.append('/Users/albertsmith/Documents/GitHub')
import pyRelaxSim as RS
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
ex=RS.ExpSys(v0H=600,Nucs='13C')
ex.set_inter(Type='CS',i=0,ppm=-20)
L=RS.Liouvillian(ex)
U=L.U(Dt=10e-5)
rho=RS.Rho(rho0='13Cx',detect='13Cp',L=L)
rho.DetProp(U,n=4096)
rho.plot(FT=True,imag=False,axis='ppm',ap)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='$\\delta$($^{13}$C) / ppm', ylabel='I / a.u.'>

# %%
rho.t_axis.shape
# Out:
# (1,)
