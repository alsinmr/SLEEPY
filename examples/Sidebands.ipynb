# %% [markdown]
# # Example: Spinning Side Bands

# %%
# git clone https://github.com/alsinmr/pyRelaxSim.git
import sys
sys.path.append('/Users/albertsmith/Documents/GitHub.nosync')
sys.path.append('/Users/albertsmith/Documents/GitHub')
import pyRelaxSim as RS
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %% [markdown]
# ## Define spin system

# %%
ex=RS.ExpSys(v0H=600,Nucs=['15N','1H'],vr=5000,pwdavg=RS.PowderAvg(q=5))
ex.set_inter(Type='dipole',i0=0,i1=1,delta=20000)
ex.set_inter(Type='CSA',i=0,delta=100)

L=RS.Liouvillian((ex))
L.add_relax(Type='T2',i=0,T2=.01)
seq=RS.Sequence(L)
seq.add_channel('1H',t=[0,L.taur/10],v1=100000)
rho=RS.Rho(rho0='15Nx',detect='15Np',L=L)

# %%
rho.clear()
rho.DetProp(seq=seq,n=2048)
# Out:
# Density Matrix/Detection Operator
# rho0: 15Nx
# detect[0]: 15Np
# Current time is 40960.000 microseconds
# 2048 time points have been recorded
#
# <pyRelaxSim.Rho.Rho object at 0x7fbb189fa2b0>

# %%
rho.plot(FT=True,imag=False)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='$\\nu$ / Hz', ylabel='I / a.u.'>

# %%
rho.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='$t$ / ms', ylabel='<15Np>'>

# %%
50*60
# Out:
# 3000
