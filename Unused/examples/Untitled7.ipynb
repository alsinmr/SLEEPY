# %%
import sys
sys.path.append('/Users/albertsmith/Documents/GitHub.nosync/')
import SLEEPY as sl

# %%
# %matplotlib notebook

# %%
ex0=sl.ExpSys(v0H=600,Nucs='2H',vr=0)
ex0.set_inter('quadrupole',i=0,delta=128000)
ex1=ex0.copy()
ex1.set_inter('quadrupole',i=0,delta=64000)
# Out:
# 1-spin system (2H)
# B0 = 14.092 T (600.000 MHz 1H frequency)
# rotor angle = 0.000 degrees
# rotor frequency = 0.0 kHz
# Temperature = 298 K
# Powder Average: JCP59 with 99 angles
# Interactions:
# 	quadrupole on spin 0 with arguments: (delta=64000)
#
# <SLEEPY.ExpSys.ExpSys object at 0x7fb579eaab80>

# %%
L=sl.Liouvillian((ex0,ex1))
L.kex=sl.Tools.twoSite_kex(tc=1e-5,p1=.3)
seq=L.Sequence().add_channel('2H',t=[0,1e-6])
# Out:
# Quadrupole Hamiltonian does not include 2nd order terms
# Quadrupole Hamiltonian does not include 2nd order terms

# %%
rho=sl.Rho(rho0='2Hx',detect='2Hp')
rho.DetProp(seq,n=100)
# Out:
# Block-Diagonal Propagation
# State reduction: 18->4
# Density Matrix/Detection Operator
# rho0: 2Hx
# detect[0]: 2Hp
# Current time is 100.000 microseconds
# 100 time points have been recorded
#
# <SLEEPY.Rho.Rho object at 0x7fb569a466a0>

# %%
rho.plot(FT=True,apodize=False,axis='MHz')
# Out:
# <img src="data:image/png;base64,..." width="1280">
# <AxesSubplot:xlabel='$\\nu$ / MHz', ylabel='I / a.u.'>
